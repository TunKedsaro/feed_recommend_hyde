# %% [markdown]
# # Template rendering

# %%
# 1. ROLE_DEFINITION
You are a query synthesis engine for a feed recommendation system.

# 2. LANGUAGE_REQUIREMENT (STRICT)
- Student preferred language: th
- If missing, default to "th"
- All query_text MUST be written in output_language

# 3. GENERATION_INSTRUCTION
Generate EXACTLY 5 feed search queries based on user interaction behavior.

# 4. STRICT_RULES
- Use UserContext AND HistorySummary
- HistorySummary MUST be the PRIMARY signal
- Extract signals from:
  - recent_tag_interaction
  - recent_category_interaction
  - recent_keyword_search
- interaction_primary MUST reflect strongest pattern
- interaction_secondary MUST differ from Q1
- profile_based used only as fallback alignment
- ai_exploration must remain relevant to interaction patterns
- Do NOT invent new themes outside interaction
- Do NOT explain
- Output JSON ONLY
- Query style: search-style keywords (no punctuation, no quotes)

# 5. LENGTH_CONSTRAINT (STRICT)
- If output_language = "en": 6-12 words
- If output_language = "th": 25-70 characters

# 6. HYDE_QUERY_STRUCTURE (EXACTLY 5)
- Q1: interaction_primary weight=1.0
- Q2: interaction_secondary (must differ from Q1) weight=1.0
- Q3: profile_based (light alignment with UserContext) weight=1.0
- Q4: ai_exploration weight=0.6
- Q5: ai_exploration (must differ from Q4) weight=0.6

# 7. OUTPUT_FORMAT (STRICT)
{
  "output_language": "th|en",
  "hyde_queries": [
    {"query_id":"Q1","query_text":"string","weight":1.0,"intent_label":"interaction_primary"},
    {"query_id":"Q2","query_text":"string","weight":1.0,"intent_label":"interaction_secondary"},
    {"query_id":"Q3","query_text":"string","weight":1.0,"intent_label":"profile_based"},
    {"query_id":"Q4","query_text":"string","weight":0.6,"intent_label":"ai_exploration"},
    {"query_id":"Q5","query_text":"string","weight":0.6,"intent_label":"ai_exploration"}
  ]
}

# 8. INPUT_CONTEXT
UserContext:
นักศึกษา: Engineering Electrical Kasetsart University
เป้าหมายอาชีพ: ไม่ระบุ
ทักษะ: [
  {"skill_id":"1001","skill_name":"Python","skill_level":"L3"},
  {"skill_id":"1002","skill_name":"Math","skill_level":"L2"},
  {"skill_id":"1003","skill_name":"Circuit Analysis","skill_level":"L2"},
  {"skill_id":"1005","skill_name":"Computer Vision","skill_level":"L3"},
  {"skill_id":"1006","skill_name":"Deep Learning","skill_level":"L2"},
  {"skill_id":"1007","skill_name":"FastAPI","skill_level":"L2"},
  {"skill_id":"1008","skill_name":"SQL","skill_level":"L2"},
  {"skill_id":"1009","skill_name":"Docker","skill_level":"L1"},
  {"skill_id":"1010","skill_name":"AWS","skill_level":"L1"}
]
กลุ่มผู้ใช้: I want a job (Guide students to tools that help then plan, act, and move closer to their career goals)
ภาษา: ไทย

HistorySummary:
พฤติกรรมผู้ใช้ในจากการ Interactive 20 ครั้งล่าสุด 
โพสต์ที่เคยดู: ai portfolio guide, build your first ai project, api design best practices, scaling systems with aws, data analyst roadmap 2026, how to prepare for job interviews, time management for students, creative portfolio for musicians, international law career guide, handling difficult customers professionally. 
แท็กที่สนใจ: ai, api, art, aws, backend, career, communication, customer, data, hospitality, interview, job, law, machine_learning, music, portfolio, productivity, project, sql, study, system_design, time_management. 
หมวดหมู่ที่สนใจ: art, career, hospitality, law, lifestyle, skill, technology. 
คำค้นหาที่ใช้ล่าสุด: ai career path, ai project idea, api scalable design, deploy ml on aws, data career roadmap, ai interview question. 
โพสต์ล่าสุดที่สนใจ: Handling Difficult Customers Professionally, International Law Career Guide, Creative Portfolio for Musicians, Time Management for Students, How to Prepare for Job Interviews.

# %% [markdown]
# <hr>

# %% [markdown]
# # stu_p4xxx
# - The same student
# - Different years
# - Gain more skill in the same direction field

# %% [markdown]
# ### stu_p4201

# %% [raw]
# {
#   "user_id": "stu_p4201",
#   "student_year": "year1",
#   "faculty_name": "Engineering",
#   "curriculum_name": "Electrical",
#   "university_name": "Kasetsart University",
#   "skill": [
#     {
#       "skill_id": "1001",
#       "skill_name": "Python",
#       "skill_level": "L1"
#     },
#     {
#       "skill_id": "1002",
#       "skill_name": "Math",
#       "skill_level": "L2"
#     }
#   ],
#   "onboard_grp": "No clear plan"
# }

# %% [raw]
# {
#   "studentId": "stu_p4201",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-106",
#       "score": 0.633694,
#       "metadata": {
#         "post_id": "FEED-106",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 09:00:00 UTC",
#         "post_topic": "Intro to Python for Beginners",
#         "post_content_body": "Start your programming journey with Python. \nLearn syntax, variables, and simple projects.",
#         "post_tags": "[\"python\",\"beginner\",\"coding\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 18000,
#         "num_like": 1200,
#         "num_comment": 60,
#         "num_share": 400,
#         "num_bookmark": 900
#       }
#     },
#     {
#       "feedId": "FEED-104",
#       "score": 0.601624,
#       "metadata": {
#         "post_id": "FEED-104",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-05 16:00:00 UTC",
#         "post_topic": "Beginner Machine Learning Projects",
#         "post_content_body": "Simple machine learning project ideas for beginners using Python. No prior experience required, suitable for first-year students starting AI journey.",
#         "post_tags": "[\"machine_learning\", \n\"beginner\", \"python\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\", \"skill\"]",
#         "num_click": 12000,
#         "num_like": 700,
#         "num_comment": 25,
#         "num_share": 200,
#         "num_bookmark": 500
#       }
#     },
#     {
#       "feedId": "FEED-114",
#       "score": 0.57609,
#       "metadata": {
#         "post_id": "FEED-114",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-14 11:00:00 UTC",
#         "post_topic": "Sustainability Careers Guide",
#         "post_content_body": "Explore career paths in environmental science \nand sustainability industries.",
#         "post_tags": "[\"environment\",\"career\",\n\"sustainability\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 12000,
#         "num_like": 650,
#         "num_comment": 35,
#         "num_share": 200,
#         "num_bookmark": 450
#       }
#     },
#     {
#       "feedId": "FEED-108",
#       "score": 0.568081,
#       "metadata": {
#         "post_id": "FEED-108",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-11 10:30:00 UTC",
#         "post_topic": "Build Your First AI Project",
#         "post_content_body": "Step-by-step guide to creating a machine \nlearning project using Python and real datasets.",
#         "post_tags": "[\"ai\",\"machine_learning\",\n\"project\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\",\"technology\"]",
#         "num_click": 20000,
#         "num_like": 1500,
#         "num_comment": 80,
#         "num_share": 500,
#         "num_bookmark": 1200
#       }
#     },
#     {
#       "feedId": "FEED-107",
#       "score": 0.566856,
#       "metadata": {
#         "post_id": "FEED-107",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 12:00:00 UTC",
#         "post_topic": "Circuit Design Fundamentals",
#         "post_content_body": "Understand basic circuit components, Ohm’s \nlaw, and how to design simple electrical systems.",
#         "post_tags": "[\"engineering\",\"circuit\",\n\"electrical\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 650
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p4202

# %% [raw]
# {
#   "user_id": "stu_p4202",
#   "student_year": "year2",
#   "faculty_name": "Engineering",
#   "curriculum_name": "Electrical",
#   "university_name": "Kasetsart University",
#   "skill": [
#     {
#       "skill_id": "1001",
#       "skill_name": "Python",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1002",
#       "skill_name": "Math",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1003",
#       "skill_name": "Circuit Analysis",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1004",
#       "skill_name": "MATLAB",
#       "skill_level": "L1"
#     }
#   ],
#   "onboard_grp": "Curious-driven learners"
# }

# %% [raw]
# {
#   "studentId": "stu_p4202",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-402",
#       "score": 0.626582,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-107",
#       "score": 0.610334,
#       "metadata": {
#         "post_id": "FEED-107",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 12:00:00 UTC",
#         "post_topic": "Circuit Design Fundamentals",
#         "post_content_body": "Understand basic circuit components, Ohm’s \nlaw, and how to design simple electrical systems.",
#         "post_tags": "[\"engineering\",\"circuit\",\n\"electrical\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 650
#       }
#     },
#     {
#       "feedId": "FEED-106",
#       "score": 0.562071,
#       "metadata": {
#         "post_id": "FEED-106",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 09:00:00 UTC",
#         "post_topic": "Intro to Python for Beginners",
#         "post_content_body": "Start your programming journey with Python. \nLearn syntax, variables, and simple projects.",
#         "post_tags": "[\"python\",\"beginner\",\"coding\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 18000,
#         "num_like": 1200,
#         "num_comment": 60,
#         "num_share": 400,
#         "num_bookmark": 900
#       }
#     },
#     {
#       "feedId": "FEED-108",
#       "score": 0.556172,
#       "metadata": {
#         "post_id": "FEED-108",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-11 10:30:00 UTC",
#         "post_topic": "Build Your First AI Project",
#         "post_content_body": "Step-by-step guide to creating a machine \nlearning project using Python and real datasets.",
#         "post_tags": "[\"ai\",\"machine_learning\",\n\"project\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\",\"technology\"]",
#         "num_click": 20000,
#         "num_like": 1500,
#         "num_comment": 80,
#         "num_share": 500,
#         "num_bookmark": 1200
#       }
#     },
#     {
#       "feedId": "FEED-104",
#       "score": 0.538493,
#       "metadata": {
#         "post_id": "FEED-104",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-05 16:00:00 UTC",
#         "post_topic": "Beginner Machine Learning Projects",
#         "post_content_body": "Simple machine learning project ideas for beginners using Python. No prior experience required, suitable for first-year students starting AI journey.",
#         "post_tags": "[\"machine_learning\", \n\"beginner\", \"python\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\", \"skill\"]",
#         "num_click": 12000,
#         "num_like": 700,
#         "num_comment": 25,
#         "num_share": 200,
#         "num_bookmark": 500
#       }
#     }
#   ]

# %% [markdown]
# ### stu_p4198

# %% [raw]
# {
#   "user_id": "stu_p4198",
#   "student_year": "year3+",
#   "faculty_name": "Engineering",
#   "curriculum_name": "Electrical",
#   "university_name": "Kasetsart University",
#   "skill": [
#     {
#       "skill_id": "1001",
#       "skill_name": "Python",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1002",
#       "skill_name": "Math",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1003",
#       "skill_name": "Circuit Analysis",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1005",
#       "skill_name": "Computer Vision",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1006",
#       "skill_name": "Deep Learning",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1007",
#       "skill_name": "FastAPI",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1008",
#       "skill_name": "SQL",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1009",
#       "skill_name": "Docker",
#       "skill_level": "L1"
#     },
#     {
#       "skill_id": "1010",
#       "skill_name": "AWS",
#       "skill_level": "L1"
#     }
#   ],
#   "onboard_grp": "I want a job"
# }

# %% [raw]
# {
#   "studentId": "stu_p4198",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-401",
#       "score": 0.654313,
#       "metadata": {
#         "post_id": "FEED-401",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 09:00:00 UTC",
#         "post_topic": "Time Management for Students",
#         "post_content_body": "Learn how to manage your time effectively, \nbalance study and life, and improve productivity.",
#         "post_tags": "[\"productivity\",\n\"time_management\",\"study\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"lifestyle\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 900,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 700
#       }
#     },
#     {
#       "feedId": "FEED-110",
#       "score": 0.646591,
#       "metadata": {
#         "post_id": "FEED-110",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-12 09:00:00 UTC",
#         "post_topic": "How to Prepare for Job Interviews",
#         "post_content_body": "Common interview questions, how to answer \nthem, and tips to stand out to recruiters.",
#         "post_tags": "[\"interview\",\"career\",\"job\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 25000,
#         "num_like": 1700,
#         "num_comment": 100,
#         "num_share": 700,
#         "num_bookmark": 1500
#       }
#     },
#     {
#       "feedId": "FEED-108",
#       "score": 0.630273,
#       "metadata": {
#         "post_id": "FEED-108",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-11 10:30:00 UTC",
#         "post_topic": "Build Your First AI Project",
#         "post_content_body": "Step-by-step guide to creating a machine \nlearning project using Python and real datasets.",
#         "post_tags": "[\"ai\",\"machine_learning\",\n\"project\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\",\"technology\"]",
#         "num_click": 20000,
#         "num_like": 1500,
#         "num_comment": 80,
#         "num_share": 500,
#         "num_bookmark": 1200
#       }
#     },
#     {
#       "feedId": "FEED-101",
#       "score": 0.614434,
#       "metadata": {
#         "post_id": "FEED-101",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-02 09:00:00 UTC",
#         "post_topic": "AI Portfolio Guide",
#         "post_content_body": "Learn how to build an AI portfolio with \nreal-world projects to impress recruiters and\n land your first job.",
#         "post_tags": "[\"ai\", \"career\", \"portfolio\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\", \"technology\"]",
#         "num_click": 15000,
#         "num_like": 900,
#         "num_comment": 40,
#         "num_share": 320,
#         "num_bookmark": 600
#       }
#     },
#     {
#       "feedId": "FEED-107",
#       "score": 0.566218,
#       "metadata": {
#         "post_id": "FEED-107",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 12:00:00 UTC",
#         "post_topic": "Circuit Design Fundamentals",
#         "post_content_body": "Understand basic circuit components, Ohm’s \nlaw, and how to design simple electrical systems.",
#         "post_tags": "[\"engineering\",\"circuit\",\n\"electrical\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 650
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p4204

# %% [raw]
# {
#   "user_id": "stu_p4204",
#   "student_year": "anyone",
#   "faculty_name": "Engineering",
#   "curriculum_name": "Electrical",
#   "university_name": "Kasetsart University",
#   "skill": [
#     {
#       "skill_id": "1001",
#       "skill_name": "Python",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1002",
#       "skill_name": "Math",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1003",
#       "skill_name": "Circuit Analysis",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1005",
#       "skill_name": "Computer Vision",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1006",
#       "skill_name": "Deep Learning",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1007",
#       "skill_name": "FastAPI",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1008",
#       "skill_name": "SQL",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1009",
#       "skill_name": "Docker",
#       "skill_level": "L1"
#     },
#     {
#       "skill_id": "1010",
#       "skill_name": "AWS",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1011",
#       "skill_name": "Data Analysis",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "1012",
#       "skill_name": "Machine Learning",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1013",
#       "skill_name": "System Design",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "1014",
#       "skill_name": "Project Management",
#       "skill_level": "L2"
#     }
#   ],
#   "onboard_grp": "Social Focus"
# }

# %% [raw]
# {
#   "studentId": "stu_p4204",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-108",
#       "score": 0.571564,
#       "metadata": {
#         "post_id": "FEED-108",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-11 10:30:00 UTC",
#         "post_topic": "Build Your First AI Project",
#         "post_content_body": "Step-by-step guide to creating a machine \nlearning project using Python and real datasets.",
#         "post_tags": "[\"ai\",\"machine_learning\",\n\"project\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\",\"technology\"]",
#         "num_click": 20000,
#         "num_like": 1500,
#         "num_comment": 80,
#         "num_share": 500,
#         "num_bookmark": 1200
#       }
#     },
#     {
#       "feedId": "FEED-106",
#       "score": 0.555902,
#       "metadata": {
#         "post_id": "FEED-106",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 09:00:00 UTC",
#         "post_topic": "Intro to Python for Beginners",
#         "post_content_body": "Start your programming journey with Python. \nLearn syntax, variables, and simple projects.",
#         "post_tags": "[\"python\",\"beginner\",\"coding\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 18000,
#         "num_like": 1200,
#         "num_comment": 60,
#         "num_share": 400,
#         "num_bookmark": 900
#       }
#     },
#     {
#       "feedId": "FEED-104",
#       "score": 0.554489,
#       "metadata": {
#         "post_id": "FEED-104",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-05 16:00:00 UTC",
#         "post_topic": "Beginner Machine Learning Projects",
#         "post_content_body": "Simple machine learning project ideas for beginners using Python. No prior experience required, suitable for first-year students starting AI journey.",
#         "post_tags": "[\"machine_learning\", \n\"beginner\", \"python\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\", \"skill\"]",
#         "num_click": 12000,
#         "num_like": 700,
#         "num_comment": 25,
#         "num_share": 200,
#         "num_bookmark": 500
#       }
#     },
#     {
#       "feedId": "FEED-107",
#       "score": 0.553822,
#       "metadata": {
#         "post_id": "FEED-107",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-10 12:00:00 UTC",
#         "post_topic": "Circuit Design Fundamentals",
#         "post_content_body": "Understand basic circuit components, Ohm’s \nlaw, and how to design simple electrical systems.",
#         "post_tags": "[\"engineering\",\"circuit\",\n\"electrical\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"education\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 650
#       }
#     },
#     {
#       "feedId": "FEED-101",
#       "score": 0.527581,
#       "metadata": {
#         "post_id": "FEED-101",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-02 09:00:00 UTC",
#         "post_topic": "AI Portfolio Guide",
#         "post_content_body": "Learn how to build an AI portfolio with \nreal-world projects to impress recruiters and\n land your first job.",
#         "post_tags": "[\"ai\", \"career\", \"portfolio\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\", \"technology\"]",
#         "num_click": 15000,
#         "num_like": 900,
#         "num_comment": 40,
#         "num_share": 320,
#         "num_bookmark": 600
#       }
#     }
#   ]
# }

# %% [markdown]
# <hr>

# %% [markdown]
# # stu_p7xxx
# - Different students
# - Different years
# - Different skill and  field

# %% [markdown]
# ### stu_p7001

# %% [raw]
# {
#   "user_id": "stu_p7001",
#   "student_year": "year1",
#   "faculty_name": "Arts",
#   "curriculum_name": "Music",
#   "university_name": "Mahidol University",
#   "skill": [
#     {
#       "skill_id": "4001",
#       "skill_name": "Guitar",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4002",
#       "skill_name": "Music Theory",
#       "skill_level": "L1"
#     },
#     {
#       "skill_id": "4003",
#       "skill_name": "Performance",
#       "skill_level": "L1"
#     }
#   ],
#   "onboard_grp": "No clear plan"
# }

# %% [raw]
# {
#   "studentId": "stu_p7001",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-402",
#       "score": 0.636449,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-113",
#       "score": 0.62493,
#       "metadata": {
#         "post_id": "FEED-113",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-13 15:00:00 UTC",
#         "post_topic": "Music Performance Techniques",
#         "post_content_body": "Improve your stage performance and \nconfidence as a musician.",
#         "post_tags": "[\"music\",\"performance\",\"art\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\",\"lifestyle\"]",
#         "num_click": 9000,
#         "num_like": 500,
#         "num_comment": 30,
#         "num_share": 150,
#         "num_bookmark": 300
#       }
#     },
#     {
#       "feedId": "FEED-227",
#       "score": 0.618697,
#       "metadata": {
#         "post_id": "FEED-227",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-22 10:00:00 UTC",
#         "post_topic": "Music Industry Career Paths",
#         "post_content_body": "Explore different career options in the music \nand entertainment industry.",
#         "post_tags": "[\"music\",\"career\",\"industry\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"art\",\"career\"]",
#         "num_click": 9500,
#         "num_like": 600,
#         "num_comment": 30,
#         "num_share": 180,
#         "num_bookmark": 350
#       }
#     },
#     {
#       "feedId": "FEED-117",
#       "score": 0.595959,
#       "metadata": {
#         "post_id": "FEED-117",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-21 16:00:00 UTC",
#         "post_topic": "Creative Portfolio for Musicians",
#         "post_content_body": "Learn how to build a strong music portfolio for \nauditions and opportunities.",
#         "post_tags": "[\"music\",\"portfolio\",\"art\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"art\",\"career\"]",
#         "num_click": 8000,
#         "num_like": 500,
#         "num_comment": 25,
#         "num_share": 150,
#         "num_bookmark": 300
#       }
#     },
#     {
#       "feedId": "FEED-114",
#       "score": 0.56765,
#       "metadata": {
#         "post_id": "FEED-114",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-14 11:00:00 UTC",
#         "post_topic": "Sustainability Careers Guide",
#         "post_content_body": "Explore career paths in environmental science \nand sustainability industries.",
#         "post_tags": "[\"environment\",\"career\",\n\"sustainability\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 12000,
#         "num_like": 650,
#         "num_comment": 35,
#         "num_share": 200,
#         "num_bookmark": 450
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p7002

# %% [raw]
# {
#   "user_id": "stu_p7002",
#   "student_year": "year2",
#   "faculty_name": "Business",
#   "curriculum_name": "Entrepreneurship",
#   "university_name": "Chulalongkorn University",
#   "skill": [
#     {
#       "skill_id": "4004",
#       "skill_name": "Business Planning",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4005",
#       "skill_name": "Market Research",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4006",
#       "skill_name": "Pitching",
#       "skill_level": "L1"
#     }
#   ],
#   "onboard_grp": "Curious-driven learners"
# }

# %% [raw]
# {
#   "studentId": "stu_p7002",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-234",
#       "score": 0.668693,
#       "metadata": {
#         "post_id": "FEED-234",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-24 09:00:00 UTC",
#         "post_topic": "Business Model Canvas Explained",
#         "post_content_body": "Learn how to design and validate business \nideas using BMC.",
#         "post_tags": "[\"business\",\"strategy\",\"startup\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"business\",\"education\"]",
#         "num_click": 12000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 250,
#         "num_bookmark": 600
#       }
#     },
#     {
#       "feedId": "FEED-112",
#       "score": 0.64099,
#       "metadata": {
#         "post_id": "FEED-112",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-13 10:00:00 UTC",
#         "post_topic": "Startup Basics for Students",
#         "post_content_body": "Introduction to entrepreneurship, idea \nvalidation, and building your first startup.",
#         "post_tags": "[\"startup\",\"business\",\n\"entrepreneur\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"business\",\"career\"]",
#         "num_click": 13000,
#         "num_like": 700,
#         "num_comment": 40,
#         "num_share": 250,
#         "num_bookmark": 600
#       }
#     },
#     {
#       "feedId": "FEED-402",
#       "score": 0.63209,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-401",
#       "score": 0.626524,
#       "metadata": {
#         "post_id": "FEED-401",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 09:00:00 UTC",
#         "post_topic": "Time Management for Students",
#         "post_content_body": "Learn how to manage your time effectively, \nbalance study and life, and improve productivity.",
#         "post_tags": "[\"productivity\",\n\"time_management\",\"study\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"lifestyle\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 900,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 700
#       }
#     },
#     {
#       "feedId": "FEED-235",
#       "score": 0.616805,
#       "metadata": {
#         "post_id": "FEED-235",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-24 11:00:00 UTC",
#         "post_topic": "Marketing Fundamentals for Beginners",
#         "post_content_body": "Understand branding, positioning, and digital marketing basics.",
#         "post_tags": "[\"marketing\",\"business\",\n\"branding\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"business\",\"education\"]",
#         "num_click": 11000,
#         "num_like": 700,
#         "num_comment": 40,
#         "num_share": 220,
#         "num_bookmark": 550
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p7003

# %% [raw]
# {
#   "user_id": "stu_p7003",
#   "student_year": "year3+",
#   "faculty_name": "Science",
#   "curriculum_name": "Environmental Science",
#   "university_name": "Chiang Mai University",
#   "skill": [
#     {
#       "skill_id": "4007",
#       "skill_name": "Field Research",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "4008",
#       "skill_name": "Sustainability Analysis",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4009",
#       "skill_name": "Report Writing",
#       "skill_level": "L2"
#     }
#   ],
#   "onboard_grp": "I want a job"
# }

# %% [raw]
# {
#   "studentId": "stu_p7003",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-233",
#       "score": 0.683346,
#       "metadata": {
#         "post_id": "FEED-233",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-23 16:00:00 UTC",
#         "post_topic": "Careers in Environmental Science",
#         "post_content_body": "Explore roles in sustainability, NGOs, and \nenvironmental consulting.",
#         "post_tags": "[\"environment\",\"career\",\n\"science\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"science\",\"career\"]",
#         "num_click": 10000,
#         "num_like": 650,
#         "num_comment": 35,
#         "num_share": 200,
#         "num_bookmark": 420
#       }
#     },
#     {
#       "feedId": "FEED-232",
#       "score": 0.650753,
#       "metadata": {
#         "post_id": "FEED-232",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-23 14:00:00 UTC",
#         "post_topic": "Climate Change Research Methods",
#         "post_content_body": "Introduction to field data collection and \nenvironmental analysis techniques.",
#         "post_tags": "[\"science\",\"environment\",\n\"research\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"science\",\"education\"]",
#         "num_click": 9500,
#         "num_like": 600,
#         "num_comment": 30,
#         "num_share": 180,
#         "num_bookmark": 400
#       }
#     },
#     {
#       "feedId": "FEED-114",
#       "score": 0.650353,
#       "metadata": {
#         "post_id": "FEED-114",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-14 11:00:00 UTC",
#         "post_topic": "Sustainability Careers Guide",
#         "post_content_body": "Explore career paths in environmental science \nand sustainability industries.",
#         "post_tags": "[\"environment\",\"career\",\n\"sustainability\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 12000,
#         "num_like": 650,
#         "num_comment": 35,
#         "num_share": 200,
#         "num_bookmark": 450
#       }
#     },
#     {
#       "feedId": "FEED-402",
#       "score": 0.620938,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-110",
#       "score": 0.613898,
#       "metadata": {
#         "post_id": "FEED-110",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-12 09:00:00 UTC",
#         "post_topic": "How to Prepare for Job Interviews",
#         "post_content_body": "Common interview questions, how to answer \nthem, and tips to stand out to recruiters.",
#         "post_tags": "[\"interview\",\"career\",\"job\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 25000,
#         "num_like": 1700,
#         "num_comment": 100,
#         "num_share": 700,
#         "num_bookmark": 1500
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p7004

# %% [raw]
# {
#   "user_id": "stu_p7004",
#   "student_year": "anyone",
#   "faculty_name": "Education",
#   "curriculum_name": "Teaching English",
#   "university_name": "Khon Kaen University",
#   "skill": [
#     {
#       "skill_id": "4010",
#       "skill_name": "English Communication",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "4011",
#       "skill_name": "Lesson Planning",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4012",
#       "skill_name": "Classroom Engagement",
#       "skill_level": "L2"
#     }
#   ],
#   "onboard_grp": "Social Focus"
# }

# %% [raw]
# {
#   "studentId": "stu_p7004",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-402",
#       "score": 0.621022,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-401",
#       "score": 0.611799,
#       "metadata": {
#         "post_id": "FEED-401",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 09:00:00 UTC",
#         "post_topic": "Time Management for Students",
#         "post_content_body": "Learn how to manage your time effectively, \nbalance study and life, and improve productivity.",
#         "post_tags": "[\"productivity\",\n\"time_management\",\"study\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"lifestyle\",\"skill\"]",
#         "num_click": 14000,
#         "num_like": 900,
#         "num_comment": 45,
#         "num_share": 300,
#         "num_bookmark": 700
#       }
#     },
#     {
#       "feedId": "FEED-236",
#       "score": 0.587159,
#       "metadata": {
#         "post_id": "FEED-236",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-24 13:00:00 UTC",
#         "post_topic": "Effective Study Techniques for University",
#         "post_content_body": "Improve memory, focus, and exam performance \nwith proven methods.",
#         "post_tags": "[\"study\",\"education\",\n\"learning\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\"]",
#         "num_click": 13000,
#         "num_like": 900,
#         "num_comment": 50,
#         "num_share": 300,
#         "num_bookmark": 700
#       }
#     },
#     {
#       "feedId": "FEED-234",
#       "score": 0.580735,
#       "metadata": {
#         "post_id": "FEED-234",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-24 09:00:00 UTC",
#         "post_topic": "Business Model Canvas Explained",
#         "post_content_body": "Learn how to design and validate business \nideas using BMC.",
#         "post_tags": "[\"business\",\"strategy\",\"startup\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"business\",\"education\"]",
#         "num_click": 12000,
#         "num_like": 800,
#         "num_comment": 45,
#         "num_share": 250,
#         "num_bookmark": 600
#       }
#     },
#     {
#       "feedId": "FEED-227",
#       "score": 0.573541,
#       "metadata": {
#         "post_id": "FEED-227",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-22 10:00:00 UTC",
#         "post_topic": "Music Industry Career Paths",
#         "post_content_body": "Explore different career options in the music \nand entertainment industry.",
#         "post_tags": "[\"music\",\"career\",\"industry\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"art\",\"career\"]",
#         "num_click": 9500,
#         "num_like": 600,
#         "num_comment": 30,
#         "num_share": 180,
#         "num_bookmark": 350
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p7005

# %% [raw]
# {
#   "user_id": "stu_p7005",
#   "student_year": "year2",
#   "faculty_name": "Law",
#   "curriculum_name": "International Law",
#   "university_name": "Thammasat University",
#   "skill": [
#     {
#       "skill_id": "4013",
#       "skill_name": "Legal Analysis",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4014",
#       "skill_name": "Case Study Review",
#       "skill_level": "L2"
#     },
#     {
#       "skill_id": "4015",
#       "skill_name": "Argumentation",
#       "skill_level": "L1"
#     }
#   ],
#   "onboard_grp": "Curious-driven learners"
# }

# %% [raw]
# {
#   "studentId": "stu_p7005",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-229",
#       "score": 0.672128,
#       "metadata": {
#         "post_id": "FEED-229",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-22 15:00:00 UTC",
#         "post_topic": "How to Analyze Legal Cases",
#         "post_content_body": "Step-by-step guide to reading and analyzing \nlegal case studies effectively.",
#         "post_tags": "[\"law\",\"analysis\",\"case_study\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"law\",\"education\"]",
#         "num_click": 8500,
#         "num_like": 500,
#         "num_comment": 20,
#         "num_share": 140,
#         "num_bookmark": 300
#       }
#     },
#     {
#       "feedId": "FEED-402",
#       "score": 0.624088,
#       "metadata": {
#         "post_id": "FEED-402",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-28 11:00:00 UTC",
#         "post_topic": "How to Learn Anything Faster",
#         "post_content_body": "Discover proven techniques to learn new skills quickly and retain knowledge longer.",
#         "post_tags": "[\"learning\",\"self_improvement\"\n,\"education\"]",
#         "post_target_group": "everyone",
#         "post_category": "[\"learning\",\n\"self_improvement\",\"education\"]",
#         "num_click": 15000,
#         "num_like": 1000,
#         "num_comment": 50,
#         "num_share": 320,
#         "num_bookmark": 800
#       }
#     },
#     {
#       "feedId": "FEED-228",
#       "score": 0.611251,
#       "metadata": {
#         "post_id": "FEED-228",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-22 13:00:00 UTC",
#         "post_topic": "International Law Career Guide",
#         "post_content_body": "Understand career paths in international law \nand global organizations.",
#         "post_tags": "[\"law\",\"career\",\"international\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"law\",\"career\"]",
#         "num_click": 9000,
#         "num_like": 550,
#         "num_comment": 25,
#         "num_share": 160,
#         "num_bookmark": 320
#       }
#     },
#     {
#       "feedId": "FEED-236",
#       "score": 0.594496,
#       "metadata": {
#         "post_id": "FEED-236",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-24 13:00:00 UTC",
#         "post_topic": "Effective Study Techniques for University",
#         "post_content_body": "Improve memory, focus, and exam performance \nwith proven methods.",
#         "post_tags": "[\"study\",\"education\",\n\"learning\"]",
#         "post_target_group": "year1",
#         "post_category": "[\"education\"]",
#         "num_click": 13000,
#         "num_like": 900,
#         "num_comment": 50,
#         "num_share": 300,
#         "num_bookmark": 700
#       }
#     },
#     {
#       "feedId": "FEED-231",
#       "score": 0.592987,
#       "metadata": {
#         "post_id": "FEED-231",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-23 11:00:00 UTC",
#         "post_topic": "Handling Difficult Customers\n Professionally",
#         "post_content_body": "Techniques to manage complaints and improve \ncustomer satisfaction.",
#         "post_tags": "[\"hospitality\",\"customer\",\n\"communication\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"hospitality\",\"skill\"]",
#         "num_click": 11000,
#         "num_like": 700,
#         "num_comment": 40,
#         "num_share": 200,
#         "num_bookmark": 500
#       }
#     }
#   ]
# }

# %% [markdown]
# ### stu_p7006

# %% [markdown]
# {
#   "user_id": "stu_p7006",
#   "student_year": "year3+",
#   "faculty_name": "Hospitality",
#   "curriculum_name": "Hotel Management",
#   "university_name": "Prince of Songkla University",
#   "skill": [
#     {
#       "skill_id": "4016",
#       "skill_name": "Front Office Operations",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "4017",
#       "skill_name": "Customer Relations",
#       "skill_level": "L3"
#     },
#     {
#       "skill_id": "4018",
#       "skill_name": "Team Coordination",
#       "skill_level": "L2"
#     }
#   ],
#   "onboard_grp": "I want a job"
# }

# %% [markdown]
# {
#   "studentId": "stu_p7006",
#   "source": "vertex_vector_search",
#   "numRecommendations": 5,
#   "recommendations": [
#     {
#       "feedId": "FEED-231",
#       "score": 0.667064,
#       "metadata": {
#         "post_id": "FEED-231",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-23 11:00:00 UTC",
#         "post_topic": "Handling Difficult Customers\n Professionally",
#         "post_content_body": "Techniques to manage complaints and improve \ncustomer satisfaction.",
#         "post_tags": "[\"hospitality\",\"customer\",\n\"communication\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"hospitality\",\"skill\"]",
#         "num_click": 11000,
#         "num_like": 700,
#         "num_comment": 40,
#         "num_share": 200,
#         "num_bookmark": 500
#       }
#     },
#     {
#       "feedId": "FEED-110",
#       "score": 0.631567,
#       "metadata": {
#         "post_id": "FEED-110",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-12 09:00:00 UTC",
#         "post_topic": "How to Prepare for Job Interviews",
#         "post_content_body": "Common interview questions, how to answer \nthem, and tips to stand out to recruiters.",
#         "post_tags": "[\"interview\",\"career\",\"job\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 25000,
#         "num_like": 1700,
#         "num_comment": 100,
#         "num_share": 700,
#         "num_bookmark": 1500
#       }
#     },
#     {
#       "feedId": "FEED-114",
#       "score": 0.607972,
#       "metadata": {
#         "post_id": "FEED-114",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-14 11:00:00 UTC",
#         "post_topic": "Sustainability Careers Guide",
#         "post_content_body": "Explore career paths in environmental science \nand sustainability industries.",
#         "post_tags": "[\"environment\",\"career\",\n\"sustainability\"]",
#         "post_target_group": "year3+",
#         "post_category": "[\"career\"]",
#         "num_click": 12000,
#         "num_like": 650,
#         "num_comment": 35,
#         "num_share": 200,
#         "num_bookmark": 450
#       }
#     },
#     {
#       "feedId": "FEED-230",
#       "score": 0.606502,
#       "metadata": {
#         "post_id": "FEED-230",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-23 09:00:00 UTC",
#         "post_topic": "Hotel Operations Management Basics",
#         "post_content_body": "Learn how hotel operations work including front \ndesk, housekeeping, and guest services.",
#         "post_tags": "[\"hospitality\",\"operations\",\n\"hotel\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"hospitality\",\"education\"]",
#         "num_click": 9000,
#         "num_like": 550,
#         "num_comment": 30,
#         "num_share": 170,
#         "num_bookmark": 350
#       }
#     },
#     {
#       "feedId": "FEED-102",
#       "score": 0.535626,
#       "metadata": {
#         "post_id": "FEED-102",
#         "post_status": "PUBLISHED",
#         "is_valid": true,
#         "post_created_at": "2026-04-03 14:30:00 UTC",
#         "post_topic": "Data Science Resume Tips",
#         "post_content_body": "Key techniques to write a strong data science \nresume that passes screening and gets interviews.",
#         "post_tags": "[\"internship\", \"data_science\", \n\"resume\"]",
#         "post_target_group": "year2",
#         "post_category": "[\"career\", \"internship\"]",
#         "num_click": 13000,
#         "num_like": 750,
#         "num_comment": 35,
#         "num_share": 250,
#         "num_bookmark": 500
#       }
#     }
#   ]
# }

# %% [markdown]
# #
